# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as img

# %% [markdown]
# from the precision investigation in the training folder we learned that
# the cells with 'MEK inhibitor' have a very high replicate precision. I want to look at those images.
# Image 1 = SQ00015096/F01/01 / sample = BRD-K85751432-001-03-3
#
# Image 2 = SQ00015100/E13/01 / sample = BRD-K82244583-001-01-3

# %% [markdown]
# The following images are the 5 channels from well SQ00015096/F01/01 which were perterbed with:
# BRD-K85751432-001-03-3, which has the MOA: MEK inhibitor

# %%
im = []
for i in range(5):
    im.append(img.imread(f'/Users/mbornhol/git/neural-profiling/baseline/01_data/example_images/r06c01f01p01-ch{i+1}sk1fk1fl1.png'))
#plt.style.use({'figure.facecolor':'white'})
fig, ax = plt.subplots(5, figsize=(50,50))
for i in range(5):
    ax[i].imshow(im[i])

# %% [markdown]
# For comparisson, here are DMSO images from right next to the above well

# %%
im = []
for i in range(5):
    im.append(img.imread(f'/Users/mbornhol/git/neural-profiling/baseline/01_data/example_images/r06c10f01p01-ch{i+1}sk1fk1fl1.png'))
#plt.style.use({'figure.facecolor':'white'})
fig, ax = plt.subplots(5, figsize=(50,50))
for i in range(5):
    ax[i].imshow(im[i])

# %% [markdown]
# Again images from a MEK inhibitor plate. Just in case it is more apparent here.

# %%
im = []
for i in range(5):
    im.append(img.imread(f'/Users/mbornhol/git/neural-profiling/baseline/01_data/example_images/r05c13f01p01-ch{i+1}sk1fk1fl1.png'))
#plt.style.use({'figure.facecolor':'white'})
fig, ax = plt.subplots(5, figsize=(50,50))
for i in range(5):
    ax[i].imshow(im[i])
