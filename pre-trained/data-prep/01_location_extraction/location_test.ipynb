# %% [markdown]
# Manually downloaded locations and a image to check their validity.

# %%
image_loc = 's3://imaging-platform/projects/2015_10_05_DrugRepurposing_AravindSubramanian_GolubLab_Broad/2016_04_01_a549_48hr_batch1_compressed/images/'
loc_loc = 's3://imaging-platform/projects/2015_10_05_DrugRepurposing_AravindSubramanian_GolubLab_Broad/workspace/deep_learning/locations/'
# r01c01f01p01-ch1sk1fk1fl1.png

# %%
from matplotlib import image
from matplotlib import pyplot as plt
import pandas as pd

# %%
locs = pd.read_csv('A01-1-Nuclei.csv')

# %%
locs = locs/2

# %%
# to read the image stored in the working directory
data = image.imread('r01c01f01p01-ch1sk1fk1fl1.png')

# to draw a point on co-ordinate (200,300)
plt.scatter(locs['Nuclei_Location_Center_X'], locs['Nuclei_Location_Center_Y'], marker='o', color="white", alpha=0.6, s= 10)
plt.imshow(data)
plt.show()
