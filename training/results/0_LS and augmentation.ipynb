# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import os
import numpy as np
from pycytominer import aggregate, annotate, normalize, feature_select, cyto_utils
from cytominer_eval import evaluate

import sys
sys.path.insert(0, "/Users/mbornhol/git/neural-profiling")
from utils import eval

# %%
one = '1021'
two = '1023'
res1 = pd.read_csv(f'../runs/{one}/results.csv')
res2 = pd.read_csv(f'../runs/{two}/results.csv')
label1 = 'auf off, 0.0 '
label2 = 'aug on, 0.1'
eval.plotting.accuracy_noloss(title="Train on batches", index1=one, label_1=label1, index2=two, label_2=label2)

# %%
eval.plotting.enrichment('Enrichment: Train on batches',  index1=res1, label_1=label1, index2=res2, label_2=label2)

# %%
eval.plotting.prec_recall('Precision@K and Recall@K: Compare batch sizes',  fontsize=13, index1=res1, label_1=label1, index2=res2, label_2=label2)

# %%
pre_r21 = 0.06158549506341898

pre_r23 = 0.05919115928790851

# %%
res2.iloc[0]
# Out:
# Unnamed: 0                0.000000
# enrichment_percentile     0.995000
# threshold                 0.371783
# ods_ratio                13.644732
# p-value                   0.000000
# k                         5.000000
# precision                 0.065967
# recall                    0.052244
# Name: 0, dtype: float64

# %%
pd.read_csv(f"accuracy/{two}.csv").iloc[-1]
# Out:
# loss       1.7389
# acc        0.8754
# val_acc    0.7188
# Name: 29, dtype: float64

# %%
one = '1024'
two = '1025'
res1 = pd.read_csv(f'../runs/{one}/results.csv')
res2 = pd.read_csv(f'../runs/{two}/results.csv')
label1 = 'auf off, 0.0 '
label2 = 'aug on, 0.1'
eval.plotting.accuracy_noloss(title="Train on batches", index1=one, label_1=label1, index2=two, label_2=label2)

# %%
eval.plotting.enrichment('Enrichment: Train on batches',  index1=res1, label_1=label1, index2=res2, label_2=label2)

# %%
eval.plotting.prec_recall('Precision@K and Recall@K: Compare batch sizes',  fontsize=13, index1=res1, label_1=label1, index2=res2, label_2=label2)

# %%
res2.iloc[0]
# Out:
# Unnamed: 0                0.000000
# enrichment_percentile     0.995000
# threshold                 0.325161
# ods_ratio                13.003610
# p-value                   0.000000
# k                         5.000000
# precision                 0.059668
# recall                    0.048612
# Name: 0, dtype: float64

# %%
pd.read_csv(f"accuracy/{one}.csv").iloc[-1]
# Out:
# loss       0.5225
# acc        0.9614
# val_acc    0.6549
# Name: 29, dtype: float64

# %%
one = '1028'
two = '1105'
res1 = pd.read_csv(f'../runs/{one}/results.csv')
res2 = pd.read_csv(f'../runs/{two}/results.csv')
label1 = 'auf on, 0.1 '
label2 = 'aug on, 0.0'
eval.plotting.accuracy_noloss(title="Train on batches", index1=one, label_1=label1, index2=two, label_2=label2)

# %%
eval.plotting.enrichment('Enrichment: Train on batches',  index1=res1, label_1=label1, index2=res2, label_2=label2)

# %%
eval.plotting.prec_recall('Precision@K and Recall@K: Compare batch sizes',  fontsize=13, index1=res1, label_1=label1, index2=res2, label_2=label2)

# %%
pd.read_csv(f"accuracy/{two}.csv").iloc[-1]
# Out:
# loss       0.8179
# acc        0.8947
# val_acc    0.6316
# Name: 29, dtype: float64

# %%
res1.iloc[0]
# Out:
# Unnamed: 0                0.000000
# enrichment_percentile     0.995000
# threshold                 0.340169
# ods_ratio                16.179841
# p-value                   0.000000
# k                         5.000000
# precision                 0.072441
# recall                    0.058689
# Name: 0, dtype: float64

# %%
res2.iloc[0]
# Out:
# Unnamed: 0                0.000000
# enrichment_percentile     0.995000
# threshold                 0.443272
# ods_ratio                15.339429
# p-value                   0.000000
# k                         5.000000
# precision                 0.070866
# recall                    0.058910
# Name: 0, dtype: float64
