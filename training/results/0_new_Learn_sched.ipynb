# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import os
import numpy as np
import sys
sys.path.insert(0, "/Users/mbornhol/git/neural-profiling")
from utils import eval

# %%
eval.plotting.accuracy(title="Batch size", index1='1024', label_1='cosine 0.02', index2='1028', label_2='Cosine 0.04', index3='1103', label_3='new LS')

# %%
res1 = pd.read_csv('../runs/1021/results.csv')
res2 = pd.read_csv('../runs/1028/results.csv')
res3 = pd.read_csv('../runs/1027/results.csv')

label1 = '21'
label2 = '1028'
label3 = '27'
